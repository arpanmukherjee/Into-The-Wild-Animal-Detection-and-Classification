# %%
# !python -m visdom.server
import json
# Out:
# Checking for scripts.
# It's Alive!
# INFO:root:Application Started
# You can navigate to http://localhost:8097
# INFO:tornado.access:200 POST /env/main (127.0.0.1) 0.85ms
# INFO:tornado.access:101 GET /vis_socket (127.0.0.1) 0.70ms
# INFO:root:Opened visdom socket from ip: 127.0.0.1
# INFO:tornado.access:200 POST /events (127.0.0.1) 0.86ms
# INFO:tornado.access:200 POST /events (127.0.0.1) 0.65ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.99ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.74ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.77ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.53ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.68ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.00ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.57ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.71ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.59ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.86ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.96ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.73ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.52ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.66ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.41ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.77ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.41ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.56ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.39ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.69ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.40ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.77ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.77ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.54ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.78ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.41ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.73ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.45ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.80ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.64ms
# INFO:tornado.access:200 GET / (192.168.62.236) 28.71ms
# INFO:tornado.access:200 GET /static/js/jquery.min.js?v=e071abda8fe61194711cfc2ab99fe104 (192.168.62.236) 12.07ms
# INFO:tornado.access:200 GET /static/css/bootstrap.min.css?v=ec3bb52a00e176a7181d454dffaea219 (192.168.62.236) 20.83ms
# INFO:tornado.access:200 GET /static/js/bootstrap.min.js?v=5869c96cc8f19086aee625d670d741f9 (192.168.62.236) 0.66ms
# INFO:tornado.access:200 GET /static/css/react-resizable-styles.css?v=9f91a8dbf4d8f7ef1399e625660405f4 (192.168.62.236) 1.17ms
# INFO:tornado.access:200 GET /static/fonts/layout_bin_packer?v=6c46683ed70fbb1443caf3531243836d (192.168.62.236) 0.52ms
# INFO:tornado.access:200 GET /static/css/react-grid-layout-styles.css?v=7dc8934d2f9ac5303b8f0bb1148152a0 (192.168.62.236) 0.44ms
# INFO:tornado.access:200 GET /static/js/react-react.min.js?v=bca103da5b5404d93783ccf73e0e9d1e (192.168.62.236) 0.45ms
# INFO:tornado.access:200 GET /static/js/react-dom.min.js?v=950495cc51ccb90612cf0fe0bb44f8f3 (192.168.62.236) 21.35ms
# INFO:tornado.access:200 GET /static/css/style.css?v=f1b2f4d2442b8263f30058d8085c1ab3 (192.168.62.236) 0.78ms
# INFO:tornado.access:200 GET /static/js/mathjax-MathJax.js?v=49565b9ce89c64da075a5a39969b366e (192.168.62.236) 36.34ms
# INFO:tornado.access:200 GET /static/js/main.js?v=4316a77ded15b92b6e884b60b72f6513 (192.168.62.236) 89.15ms
# INFO:tornado.access:200 GET /static/js/plotly-plotly.min.js?v=00dcca8ba45aab5f63dc7fc55a544d3d (192.168.62.236) 955.02ms
# INFO:tornado.access:200 GET /static/fonts/glyphicons-halflings-regular.woff2 (192.168.62.236) 1.42ms
# INFO:tornado.access:101 GET /socket (192.168.62.236) 0.96ms
# INFO:root:Opened new socket from ip: 192.168.62.236
# INFO:tornado.access:200 POST /env/main (192.168.62.236) 1.10ms
# INFO:tornado.access:200 POST /env/main (192.168.62.236) 0.75ms
# INFO:tornado.access:200 GET /favicon.png (192.168.62.236) 2.64ms
# INFO:tornado.access:200 GET /extensions/MathMenu.js?V=2.7.1 (192.168.62.236) 3.22ms
# INFO:tornado.access:200 GET /extensions/MathZoom.js?V=2.7.1 (192.168.62.236) 2.80ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.82ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.04ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.59ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.04ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.91ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.22ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.79ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.79ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.80ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.68ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.70ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.78ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.01ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.59ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.07ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 6.41ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.44ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.73ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.01ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 2.20ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.48ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.09ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.46ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.57ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.84ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.89ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.78ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.83ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.80ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.92ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.22ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.91ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.22ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.79ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.17ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.87ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.02ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.92ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.95ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.58ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.85ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.60ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.87ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.93ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.98ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 10.47ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 15.06ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.87ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.16ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.61ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.70ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 2.59ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.82ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.69ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.84ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.76ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.11ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.04ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.74ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.88ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.79ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.89ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.50ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.84ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.45ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.70ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.95ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.09ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.63ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.81ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.48ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.76ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.55ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.79ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.68ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.80ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.98ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.69ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.02ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.43ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.74ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.05ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.19ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.56ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.96ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.78ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.23ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.45ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.56ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.95ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.81ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.97ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.43ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.81ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.60ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.84ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.06ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.00ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.45ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.68ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.52ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.71ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.21ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 2.65ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.92ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 2.07ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.68ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.95ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.75ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.92ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.97ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.21ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.75ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.11ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.49ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.80ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.12ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 21.36ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.70ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.16ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.74ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.07ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.56ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.01ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.27ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.18ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.99ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.74ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.24ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.89ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.61ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.60ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.14ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.01ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.62ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.83ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.88ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.56ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.02ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.67ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.54ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.86ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.44ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.45ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.81ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 10.17ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.52ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.16ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.82ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.01ms
# INFO:tornado.access:200 POST /env/main (127.0.0.1) 0.56ms
# INFO:tornado.access:101 GET /vis_socket (127.0.0.1) 0.45ms
# INFO:root:Opened visdom socket from ip: 127.0.0.1
# INFO:tornado.access:200 POST /events (127.0.0.1) 0.88ms
# INFO:tornado.access:200 POST /events (127.0.0.1) 0.78ms
# INFO:root:from web client: {"cmd":"close","data":"window_370b88d6848cae","eid":"main"}
# INFO:root:closing window window_370b88d6848cae
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.71ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.87ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.58ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.58ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.54ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.69ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.04ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.45ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.55ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.59ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.70ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.86ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.81ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.65ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.89ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.69ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.54ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.91ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.11ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.00ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.90ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.89ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.82ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.08ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 4.89ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.59ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.67ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.76ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.01ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.60ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.77ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.70ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.98ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.47ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.55ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.51ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.93ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.76ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 2.58ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 4.87ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.88ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.79ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.53ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.74ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.74ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 2.14ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.73ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.07ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.99ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.60ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 3.43ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.75ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.82ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.80ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.15ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.53ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.31ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.52ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.63ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.53ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.69ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.85ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.77ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.63ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.99ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.48ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.67ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.77ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.71ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.83ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.63ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.78ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.77ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.11ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.60ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.88ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.46ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.79ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.78ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.00ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.60ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.76ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 6.89ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 5.99ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.57ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.82ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.04ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.92ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 52.99ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.01ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.43ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.84ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.92ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.63ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.19ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.83ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.63ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.97ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.96ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.98ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.70ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.04ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.81ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 6.34ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.60ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.83ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.47ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.68ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.65ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.94ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.48ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.75ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.57ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 3.00ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.85ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.47ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.85ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.51ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.79ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 14.41ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.86ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.59ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.83ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.43ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.85ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.69ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.08ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.71ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.07ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 9.07ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.21ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.70ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.98ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.65ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.91ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.79ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.98ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.60ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.86ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 36.53ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.90ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.44ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.14ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.89ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.45ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.73ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.22ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.88ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 3.33ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.05ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.85ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.47ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.28ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.90ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.85ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.85ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.61ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.75ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.52ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.08ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.86ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.06ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.45ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.91ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.46ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.75ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.65ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.96ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.46ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.77ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.52ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.15ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.44ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.75ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.51ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.80ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.13ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.67ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.23ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.47ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.93ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.82ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.94ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.61ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.22ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.69ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.96ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.22ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.44ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.20ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.65ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.06ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.44ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.76ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.73ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.24ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.61ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 2.21ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.66ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.61ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.56ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.15ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.48ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.52ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.78ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.22ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.75ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.17ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.17ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 11.00ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.73ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.32ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.12ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.18ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.43ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.09ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.70ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.39ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.86ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.20ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 2.37ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 0.99ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 5.77ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 6.02ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.83ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.69ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.46ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.08ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.86ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 5.74ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.63ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.13ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.48ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.26ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.81ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.51ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.23ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.45ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.11ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.89ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.39ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.47ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.02ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.81ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.24ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.24ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.80ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.23ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.71ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.15ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.65ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.22ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.39ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.52ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.77ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.65ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.53ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.60ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.39ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.61ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.25ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.56ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 3.67ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.47ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.44ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.92ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.49ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.63ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.09ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.21ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.83ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.60ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.01ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.27ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.63ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.18ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.79ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.05ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.61ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.07ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.75ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.28ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.11ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.63ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.24ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.05ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 2.41ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.46ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.20ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.89ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.86ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.28ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.47ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.05ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.57ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.32ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.48ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.68ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.45ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.51ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.19ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 2.34ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.50ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.25ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.84ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 6.47ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.56ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.09ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.88ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.18ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 3.41ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.73ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 5.00ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.27ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.49ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.35ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.63ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.22ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.57ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.14ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.06ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 2.14ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.35ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.69ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 3.53ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.80ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.68ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.90ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 2.01ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.04ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.43ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.58ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.32ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.73ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 2.00ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.66ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.36ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.71ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 2.47ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.61ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.49ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 2.21ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 10.11ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.61ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.31ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.80ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 2.05ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.49ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.11ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.83ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.78ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.77ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.33ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.60ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.17ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.44ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.92ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.62ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.14ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.43ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.45ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.32ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.11ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 2.71ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.77ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 2.20ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.69ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.28ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.76ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.28ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.56ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.33ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.49ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.75ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.61ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.27ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.36ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 3.11ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.51ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.54ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 6.58ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.43ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.73ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 11.42ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.54ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.55ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.44ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.30ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.50ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.41ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.59ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.39ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.20ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.71ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.91ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.33ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.24ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 3.69ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.65ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.35ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.79ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.67ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.46ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.20ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.45ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.33ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.89ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.89ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.56ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.37ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.61ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.19ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.51ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.35ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.50ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.19ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.57ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.67ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.80ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 3.87ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.79ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.62ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.45ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.19ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.87ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 5.47ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.96ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 11.27ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.30ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.46ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.30ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 10.15ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.43ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.47ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.38ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.65ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.20ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.61ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.34ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.52ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.48ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.83ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.76ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.90ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.94ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 2.04ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.38ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.83ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 14.97ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.79ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 4.04ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 9.39ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.79ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.78ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.54ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.92ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.93ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.61ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.32ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.60ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.35ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.26ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.41ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.53ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.28ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.61ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.55ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.41ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 6.10ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.80ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.57ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 2.47ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.50ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.66ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.50ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.55ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.33ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.55ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.51ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 30.19ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.50ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 6.53ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.93ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.49ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.51ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.68ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.58ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.53ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.36ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.63ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.45ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.70ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 3.41ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.73ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.60ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.54ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.96ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.91ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 2.92ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.77ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.58ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.63ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.47ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.86ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.49ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.37ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 2.11ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.67ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 5.81ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.32ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 11.87ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.50ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.91ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.45ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 4.55ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 10.44ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 13.80ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.80ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.63ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.63ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 4.13ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.67ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.56ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.61ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.83ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.49ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.37ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.49ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.65ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.65ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 5.44ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.45ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.43ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.74ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 9.22ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.65ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.83ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.38ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.56ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.92ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.46ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.45ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.78ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.86ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.67ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.53ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.80ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 1.41ms
# ...
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.44ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.55ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.84ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.49ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.97ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.68ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 12.07ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 20.01ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.79ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 12.14ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.51ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.10ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.63ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 11.41ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.46ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.99ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.53ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.86ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.53ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.67ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 13.49ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.73ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.83ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.54ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 13.77ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.87ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.21ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.53ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 21.88ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.53ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.76ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.66ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.22ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.46ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.90ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.73ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 11.37ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.69ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.65ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.63ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.96ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 13.15ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.08ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.47ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.15ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.40ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.49ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.20ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 9.81ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.89ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.66ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.11ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.70ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.27ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.82ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.74ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 4.06ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.36ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 5.49ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.71ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.60ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.07ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.55ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.78ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.67ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.17ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.46ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.60ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.66ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.31ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.77ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 22.72ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.82ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 32.65ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.63ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.97ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.46ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.89ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 10.09ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.96ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.09ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.48ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.71ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 2.92ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.40ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.46ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 10.21ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.92ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 17.04ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 5.43ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 13.17ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.94ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 21.42ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.71ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.34ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 3.09ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.30ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.49ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.75ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.52ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 10.96ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.82ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 14.08ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.10ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.19ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.96ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 25.74ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.80ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 13.47ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.67ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.73ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.95ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 10.22ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.14ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 14.27ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.93ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.26ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.86ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 21.13ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.47ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 10.01ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.94ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 32.22ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.00ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.53ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.02ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.38ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 6.00ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 23.58ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.21ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.72ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.81ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.45ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.30ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.49ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.62ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.48ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.89ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.68ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.74ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.66ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 14.81ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.48ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.18ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.45ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.95ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.70ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.12ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.45ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.40ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.50ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 10.00ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.56ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.00ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.93ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.77ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.65ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.32ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.47ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.97ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.44ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.69ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.82ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 11.09ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.49ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.89ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.82ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 14.45ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.47ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 13.99ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.57ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 27.29ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.63ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.84ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 1.76ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.79ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.83ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 17.19ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.69ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.71ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.45ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.40ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.68ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 10.38ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.70ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 20.61ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.53ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 11.35ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.46ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.70ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 43.82ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.48ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.71ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.16ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.80ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.51ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.85ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.52ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.57ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 10.61ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.65ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 11.73ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.84ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.60ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 5.80ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.20ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.47ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 14.23ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.83ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.81ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.61ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.41ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 20.98ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.55ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.03ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.59ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.77ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.55ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.52ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.50ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.92ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.53ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.42ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.61ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 16.39ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.48ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.65ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.56ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 9.89ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.64ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.63ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.66ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.29ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.62ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 19.22ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.48ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.95ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.46ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.57ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.55ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 11.55ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.58ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.86ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.47ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.17ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.97ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 22.34ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.77ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.45ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.76ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 11.63ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.67ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.12ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.78ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.83ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.49ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.55ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.54ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.21ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.47ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 12.28ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.56ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 7.85ms
# INFO:tornado.access:200 POST /win_exists (127.0.0.1) 0.72ms
# INFO:tornado.access:200 POST /update (127.0.0.1) 8.76ms

# %%
'%.2f' % 3.46345

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from layers import *
from data import voc, coco
import os

class SEBlock(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SEBlock, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(channel, channel // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channel // reduction, channel, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1, 1)
        return x * y.expand_as(x)


class SSD(nn.Module):
    """Single Shot Multibox Architecture
    The network is composed of a base VGG network followed by the
    added multibox conv layers.  Each multibox layer branches into
        1) conv2d for class conf scores
        2) conv2d for localization predictions
        3) associated priorbox layer to produce default bounding
           boxes specific to the layer's feature map size.
    See: https://arxiv.org/pdf/1512.02325.pdf for more details.

    Args:
        phase: (string) Can be "test" or "train"
        size: input image size
        base: VGG16 layers for input, size of either 300 or 500
        extras: extra layers that feed to multibox loc and conf layers
        head: "multibox head" consists of loc and conf conv layers
    """

    def __init__(self, phase, size, base, extras, head, num_classes, channels=[256,512,128, 256, 128, 256, 128, 256]):
        super(SSD, self).__init__()
        self.phase = phase
        self.num_classes = num_classes
        self.cfg = (coco, voc)[num_classes == 17]
        self.priorbox = PriorBox(self.cfg)
        with torch.no_grad():
            self.priors = Variable(self.priorbox.forward())
            # self.priors = Variable(self.priorbox.forward(), volatile=True)
        self.size = size
        
        #arpan edit
        self.se = []
        for c in channels:
            self.se.append(SEBlock(channel=c))
        
        # SSD network
        self.vgg = nn.ModuleList(base)
        # Layer learns to scale the l2 normalized features from conv4_3
        self.L2Norm = L2Norm(512, 20)
        self.extras = nn.ModuleList(extras)

        self.loc = nn.ModuleList(head[0])
        self.conf = nn.ModuleList(head[1])

        if phase == 'test':
            self.softmax = nn.Softmax(dim=-1)
            self.detect = Detect(num_classes, 0, 200, 0.01, 0.45)

    def forward(self, x):
        """Applies network layers and ops on input image(s) x.

        Args:
            x: input image or batch of images. Shape: [batch,3,300,300].

        Return:
            Depending on phase:
            test:
                Variable(tensor) of output class label predictions,
                confidence score, and corresponding location predictions for
                each object detected. Shape: [batch,topk,7]

            train:
                list of concat outputs from:
                    1: confidence layers, Shape: [batch*num_priors,num_classes]
                    2: localization layers, Shape: [batch,num_priors*4]
                    3: priorbox layers, Shape: [2,num_priors*4]
        """
        sources = list()
        loc = list()
        conf = list()

        # apply vgg up to conv4_3 relu
        for k in range(23):
            x = self.vgg[k](x)

        s = self.L2Norm(x)
        sources.append(s)

        # apply vgg up to fc7
        for k in range(23, len(self.vgg)):
            x = self.vgg[k](x)
        sources.append(x)

        # apply extra layers and cache source layer outputs
        for k, v in enumerate(self.extras):
            x = F.relu(v(x), inplace=True)
            x = self.se[k](x)
            if k % 2 == 1:
                sources.append(x)

        # apply multibox head to source layers
        for (x, l, c) in zip(sources, self.loc, self.conf):
            loc.append(l(x).permute(0, 2, 3, 1).contiguous())
            conf.append(c(x).permute(0, 2, 3, 1).contiguous())

        loc = torch.cat([o.view(o.size(0), -1) for o in loc], 1)
        conf = torch.cat([o.view(o.size(0), -1) for o in conf], 1)
        if self.phase == "test":
            output = self.detect(
                loc.view(loc.size(0), -1, 4),                   # loc preds
                self.softmax(conf.view(conf.size(0), -1,
                             self.num_classes)),                # conf preds
                self.priors.type(type(x.data))                  # default boxes
            )
        else:
            output = (
                loc.view(loc.size(0), -1, 4),
                conf.view(conf.size(0), -1, self.num_classes),
                self.priors
            )
        return output

    def load_weights(self, base_file):
        other, ext = os.path.splitext(base_file)
        if ext == '.pkl' or '.pth':
            print('Loading weights into state dict...')
            self.load_state_dict(torch.load(base_file,
                                 map_location=lambda storage, loc: storage))
            print('Finished!')
        else:
            print('Sorry only .pth and .pkl files supported.')


# This function is derived from torchvision VGG make_layers()
# https://github.com/pytorch/vision/blob/master/torchvision/models/vgg.py
def vgg(cfg, i, batch_norm=False):
    layers = []
    in_channels = i
    for v in cfg:
        if v == 'M':
            layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
        elif v == 'C':
            layers += [nn.MaxPool2d(kernel_size=2, stride=2, ceil_mode=True)]
        else:
            conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=1)
            if batch_norm:
                layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
            else:
                layers += [conv2d, nn.ReLU(inplace=True)]
            in_channels = v
    pool5 = nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
    conv6 = nn.Conv2d(512, 1024, kernel_size=3, padding=6, dilation=6)
    conv7 = nn.Conv2d(1024, 1024, kernel_size=1)
    layers += [pool5, conv6,
               nn.ReLU(inplace=True), conv7, nn.ReLU(inplace=True)]
    return layers


def add_extras(cfg, i, batch_norm=False):
    # Extra layers added to VGG for feature scaling
    layers = []
    in_channels = i
    flag = False
    for k, v in enumerate(cfg):
        if in_channels != 'S':
            if v == 'S':
                layers += [nn.Conv2d(in_channels, cfg[k + 1],
                           kernel_size=(1, 3)[flag], stride=2, padding=1)]
            else:
                layers += [nn.Conv2d(in_channels, v, kernel_size=(1, 3)[flag])]
            flag = not flag
        in_channels = v
    return layers


def multibox(vgg, extra_layers, cfg, num_classes):
    loc_layers = []
    conf_layers = []
    vgg_source = [21, -2]
    for k, v in enumerate(vgg_source):
        loc_layers += [nn.Conv2d(vgg[v].out_channels,
                                 cfg[k] * 4, kernel_size=3, padding=1)]
        conf_layers += [nn.Conv2d(vgg[v].out_channels,
                        cfg[k] * num_classes, kernel_size=3, padding=1)]
    for k, v in enumerate(extra_layers[1::2], 2):
        loc_layers += [nn.Conv2d(v.out_channels, cfg[k]
                                 * 4, kernel_size=3, padding=1)]
        conf_layers += [nn.Conv2d(v.out_channels, cfg[k]
                                  * num_classes, kernel_size=3, padding=1)]
    return vgg, extra_layers, (loc_layers, conf_layers)


base = {
    '300': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'C', 512, 512, 512, 'M',
            512, 512, 512],
    '512': [],
}
extras = {
    '300': [256, 'S', 512, 128, 'S', 256, 128, 256, 128, 256],
    '512': [],
}
mbox = {
    '300': [4, 6, 6, 6, 4, 4],  # number of boxes per feature map location
    '512': [],
}


def build_ssd(phase, size=300, num_classes=17):
    if phase != "test" and phase != "train":
        print("ERROR: Phase: " + phase + " not recognized")
        return
    if size != 300:
        print("ERROR: You specified size " + repr(size) + ". However, " +
              "currently only SSD300 (size=300) is supported!")
        return
    base_, extras_, head_ = multibox(vgg(base[str(size)], 3),
                                     add_extras(extras[str(size)], 1024),
                                     mbox[str(size)], num_classes)
    print(base_)
    return SSD(phase, size, base_, extras_, head_, num_classes)
